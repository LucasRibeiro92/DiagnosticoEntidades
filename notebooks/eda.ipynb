# %%
from pathlib import Path

# Criar estrutura de diretórios padrão para o projeto novamente após reset
base_path = Path("C:/PythonProjects/diagnosticoentidades")
notebooks_path = base_path / "notebooks"
data_path = base_path / "data"
output_path = base_path / "results"

# Criar os diretórios
notebooks_path.mkdir(parents=True, exist_ok=True)
data_path.mkdir(parents=True, exist_ok=True)
output_path.mkdir(parents=True, exist_ok=True)

# Criar um notebook base para análise exploratória
notebook_content = """{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Análise Exploratória de Dados (EDA)\\n",
    "Dataset: Execuções de Entidades"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Setup Inicial"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\\n",
    "import matplotlib.pyplot as plt\\n",
    "import seaborn as sns\\n",
    "import numpy as np\\n",
    "import warnings\\n",
    "warnings.filterwarnings('ignore')\\n",
    "\\n",
    "# Leitura do dataset\\n",
    "df = pd.read_csv('../data/processed_data.csv', parse_dates=['data_execucao'])\\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Análise Univariada"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.describe()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.histplot(df['tempo_execucao_seg'], kde=True);"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Análise Bivariada"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.boxplot(data=df, x='status_execucao', y='tempo_execucao_seg');"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Séries Temporais"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.set_index('data_execucao').resample('M')['id_execucao'].count().plot(title='Execuções por Mês');"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. Outliers"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.boxplot(x=df['tempo_execucao_seg']);"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 6. Regras de Negócio & Testes"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.groupby(['servidor', 'status_execucao']).size().unstack().plot(kind='bar', stacked=True);"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}"""

notebook_path = notebooks_path / "eda_execucoes.ipynb"
notebook_path.write_text(notebook_content)

notebook_path.relative_to(Path("/PythonProjects/diagnosticoentidades/"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-083686b3f50f> in <module>
#     156 notebook_path.write_text(notebook_content)
#     157
# --> 158 notebook_path.relative_to(Path("/PythonProjects/diagnosticoentidades/"))
#
# ~\.conda\envs\diagnosticoentidades\lib\pathlib.py in relative_to(self, *other)
#     872             formatted = self._format_parsed_parts(to_drv, to_root, to_parts)
#     873             raise ValueError("{!r} does not start with {!r}"
# --> 874                              .format(str(self), str(formatted)))
#     875         return self._from_parsed_parts('', root if n == 1 else '',
#     876                                        abs_parts[n:])
#
# ValueError: 'C:\\PythonProjects\\diagnosticoentidades\\notebooks\\eda_execucoes.ipynb' does not start with '\\PythonProjects\\diagnosticoentidades'

# %%
from pathlib import Path

# Criar estrutura de diretórios padrão para o projeto novamente após reset
base_path = Path("C:/PythonProjects/diagnosticoentidades")
notebooks_path = base_path / "notebooks"
data_path = base_path / "data"
output_path = base_path / "results"

# Criar os diretórios
notebooks_path.mkdir(parents=True, exist_ok=True)
data_path.mkdir(parents=True, exist_ok=True)
output_path.mkdir(parents=True, exist_ok=True)

# Criar um notebook base para análise exploratória
notebook_content = """{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Análise Exploratória de Dados (EDA)\\n",
    "Dataset: Execuções de Entidades"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 1. Setup Inicial"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\\n",
    "import matplotlib.pyplot as plt\\n",
    "import seaborn as sns\\n",
    "import numpy as np\\n",
    "import warnings\\n",
    "warnings.filterwarnings('ignore')\\n",
    "\\n",
    "# Leitura do dataset\\n",
    "df = pd.read_csv('../data/processed_data.csv', parse_dates=['data_execucao'])\\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 2. Análise Univariada"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.describe()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.histplot(df['tempo_execucao_seg'], kde=True);"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 3. Análise Bivariada"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.boxplot(data=df, x='status_execucao', y='tempo_execucao_seg');"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 4. Séries Temporais"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.set_index('data_execucao').resample('M')['id_execucao'].count().plot(title='Execuções por Mês');"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 5. Outliers"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "sns.boxplot(x=df['tempo_execucao_seg']);"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "## 6. Regras de Negócio & Testes"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "df.groupby(['servidor', 'status_execucao']).size().unstack().plot(kind='bar', stacked=True);"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": ""
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}"""

notebook_path = notebooks_path / "eda_execucoes.ipynb"
notebook_path.write_text(notebook_content)

notebook_path.relative_to(Path("/PythonProjects/diagnosticoentidades/"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-083686b3f50f> in <module>
#     156 notebook_path.write_text(notebook_content)
#     157
# --> 158 notebook_path.relative_to(Path("/PythonProjects/diagnosticoentidades/"))
#
# ~\.conda\envs\diagnosticoentidades\lib\pathlib.py in relative_to(self, *other)
#     872             formatted = self._format_parsed_parts(to_drv, to_root, to_parts)
#     873             raise ValueError("{!r} does not start with {!r}"
# --> 874                              .format(str(self), str(formatted)))
#     875         return self._from_parsed_parts('', root if n == 1 else '',
#     876                                        abs_parts[n:])
#
# ValueError: 'C:\\PythonProjects\\diagnosticoentidades\\notebooks\\eda_execucoes.ipynb' does not start with '\\PythonProjects\\diagnosticoentidades'
